# %% [markdown]
# # Expressions

# %% [markdown]
# Let's start with the classic formula `2+2`

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# **Expressions** are always evaluated to a single value.

# %%
print(2+2)
# Out:
# 4

# %%
str(2+2)
# Out:
# '4'

# %%
2
# Out:
# 2

# %% [markdown]
# # Error message types

# %%
2 +
# Out:
#   File "<ipython-input-6-8b8e0fea6fab>", line 1
#     2 +
#        ^
# SyntaxError: invalid syntax

# %%
2 + '2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-82150feed70c> in <cell line: 1>()
# ----> 1 2 + '2'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
2
 2
# Out:
#   File "<ipython-input-8-d7f29c3178ff>", line 2
#     2
#     ^
# IndentationError: unexpected indent

# %%
2 + ++ 2
# Out:
# 4

# %%
2 +++ 2
# Out:
# 4

# %%
2 - ++ 2
# Out:
# 0

# %% [markdown]
# Is whitespace inside strings also ignored?

# %%
'hello     world'
# Out:
# 'hello     world'

# %%
'hello '      + 'world'
# Out:
# 'hello world'

# %% [markdown]
# # Operators

# %%
-2+24/8
# Out:
# 1.0

# %%
(-2+24)/8
# Out:
# 2.75

# %%
 2 + 3 * 6
# Out:
# 20

# %%
(2 + 3) * 6
# Out:
# 30

# %%
487347465 * 344958
# Out:
# 168114406831470

# %%
2**8
# Out:
# 256

# %% [markdown]
# Check later: What is the `^` operator in Python?

# %%
23 / 7
# Out:
# 3.2857142857142856

# %%
23 // 7
# Out:
# 3

# %%
2     +     2
# Out:
# 4

# %%
(5-1) * ((7 + 1)//(3-1))
# Out:
# 16

# %% [markdown]
# # Variables
#
# Python is dynamically typed: it decides at "runtime" what the data type of a variable is.

# %%
2.0
# Out:
# 2.0

# %%
type(-2)
# Out:
# int

# %%
type(2)
# Out:
# int

# %%
type(1.25)
# Out:
# float

# %%
type('a')
# Out:
# str

# %%
type('name')
# Out:
# str

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b152ec05ccbc> in <cell line: 1>()
# ----> 1 type(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # String concatenation and replication

# %%
'Alice' + 'Bob'
# Out:
# 'AliceBob'

# %%
'Alice' + 42
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4e9a9e71481a> in <cell line: 1>()
# ----> 1 'Alice' + 42
#
# TypeError: can only concatenate str (not "int") to str

# %%
'Alice' + str(42)
# Out:
# 'Alice42'

# %%
'Alice' + str(Bob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e155da5caa8f> in <cell line: 1>()
# ----> 1 'Alice' + str(Bob)
#
# NameError: name 'Bob' is not defined

# %%
Bob = 42
'Alice' + str(Bob)
# Out:
# 'Alice42'

# %%
'Alice' * 'Bob'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9caa30780052> in <cell line: 1>()
# ----> 1 'Alice' * 'Bob'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
'Alice' * 5.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-43325524c797> in <cell line: 1>()
# ----> 1 'Alice' * 5.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
'Alice' * 5
# Out:
# 'AliceAliceAliceAliceAlice'

# %%
'Alice' * int(5.0)
# Out:
# 'AliceAliceAliceAliceAlice'
